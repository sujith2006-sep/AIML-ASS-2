# %% [markdown]
# <a href="https://colab.research.google.com/github/SUSHWANTH1567/23CSBTB29/blob/main/assignment2_16_08_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_excel("/aiml  1.xlsx")
print(data)
# Out:
#     sid   student name coarse  contact number  Joined branch  YEAR
# 0   2000      KARTHIK   BTECH      9218524545    2023    CSE     2
# 1   2001       ANURATH  BTECH      6542987425    2023    CSE     2
# 2   2002     RAMCHARAN  BTECH      2468425461    2023    CSE     2
# 3   2003     SUSHWANTH  BTECH      2157564123    2023    ECE     2
# 4   2004         vivek  BTECH      4568751235    2023    MEC     2
# 5   2005        satwik  BTECH       149554554    2023  CIVIL     2
# 6   2006    vishwanadh  BTECH      9999999999    2023    CSE     2
# 7   2007       basheer  BTECH      4568712365    2023    CSE     2
# 8   2008         sunil  BTECH      7894512365    2023    CSE     2
# 9   2009           SAM  BTECH      7894561237    2023  CIVIL     2
# 10  2010       RAKESH   BTECH      7979797979    2023  CIVIL     2
# 11  2011        RAJESH  BTECH      8989898989    2023  CIVIL     2
# 12  2012        MANISH  BTECH      6666666666    2023    ECE     2
# ...

# %%
import pandas as pd
data = pd.read_csv("/heart.csv")
print(data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import pandas as pd
data = pd.read_csv("/games_dataset.csv")
print(data)
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...

# %%
import matplotlib.pyplot as plt
people = ['Kiran', 'Arun', 'Vijay', 'Varun']
age = [56, 45, 75, 69]
height = [200, 157, 165, 177]
weight = [100, 55, 65, 85]

# %%
import matplotlib.pyplot as plt

plt.scatter(height, weight)
plt.title('Scatter Plot: Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
plt.bar(people, height, color='blue')
plt.title('Bar Chart: Height of People')
plt.xlabel('People')
plt.ylabel('Height (cm)')
plt.show()

# %%
plt.hist(age, bins=5, color='green')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()
